# %%
import datetime
import sys
import pandas as pd
sys.path.append('../common/')
sys.path.append('../data/')
pd.set_option("mode.chained_assignment", None)
print(sys.version)
# Out:
# 3.10.6 (main, Oct  7 2022, 20:19:58) [GCC 11.2.0]

# %%
from utils import snowflake_query_from_file
# Out:
# /opt/conda/lib/python3.10/site-packages/snowflake/connector/options.py:103: UserWarning: You have an incompatible version of 'pyarrow' installed (13.0.0), please install a version that adheres to: 'pyarrow<10.1.0,>=10.0.1; extra == "pandas"'
#   warn_incompatible_dep(

# %%
# need to adjust based on requirements
QUERY_FILE_PATH = '../sql/sequence_query.sql'
OUPPUT_PATH = '../data/sequence_20230101_test.csv'
DELIMITER = '|'

# %%
result_df = snowflake_query_from_file(QUERY_FILE_PATH)
result_df.to_csv(OUPPUT_PATH, index=False, sep=DELIMITER)
# Out:
# xiangping@getflex.com
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ...

# %%
result_df

# %%
import requests

template_id = '29482818'
# Define the URL you want to send the GET request to
# url = f'http://api.hubapi.com/content/api/v2/templates/{template_id}'
# url = 'https://api.hubapi.com/crm/v3/objects/contacts'
url = 'http://api.hubapi.com/content/api/v2/templates/27827396949'
TOKEN = 'pat-na1-a858c7a3-d9ee-459a-b996-c30c45544ba4'
# Define custom headers as a dictionary
headers = {
      'Authorization': f'Bearer {TOKEN}',
      'Accept': 'application/json'
}
print(url)
print(headers)

# Send the GET request with custom headers
response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the response content (usually HTML or JSON data)
    print(response.text)
else:
    print(f"HTTP GET request failed with status code {response.status_code}")

# %%
QUERY_FILE_PATH = '../sql/deal_query.sql'
result_df = snowflake_query_from_file(QUERY_FILE_PATH)
# Out:
# snowflake_user:xiangping@getflex.com
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ...

# %%
result_df
# Out:
#          DEAL_ID DEAL_TYPE_ID                               DEAL_NAME  \
# 0    10675754574          0-3          Rockhill Management - New Deal
# 1     9423811158          0-3               West Shore LLC - New Deal
# 2    10675754574          0-3          Rockhill Management - New Deal
# 3     9423811158          0-3               West Shore LLC - New Deal
# 4    10675754574          0-3          Rockhill Management - New Deal
# ..           ...          ...                                     ...
# 243  10675754574          0-3          Rockhill Management - New Deal
# 244  10675754574          0-3          Rockhill Management - New Deal
# 245  13587913789          0-3  Corcoran Management Company - New Deal
# 246  13587913789          0-3  Corcoran Management Company - New Deal
# 247  13587913789          0-3  Corcoran Management Company - New Deal
#
#      DEAL_STAGE    DEAL_TYPE        DEAL_UPDATE_DATE DEAL_AMOUNT  \
# ...

# %%
# !pip install --upgrade sagemaker datasets

# %%
print(hello)
